# %%
import pandas as pd
import numpy as np

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
canada = pd.read_csv('CAvideos.csv')
germany = pd.read_csv('DEvideos.csv')
france = pd.read_csv('FRvideos.csv')
uk = pd.read_csv('GBvideos.csv')
india = pd.read_csv('INvideos.csv')
japan = pd.read_csv('JPvideos.csv', engine='python')
korea = pd.read_csv('KRvideos.csv', engine='python')
mexico = pd.read_csv('MXvideos.csv', engine='python')
russia = pd.read_csv('RUvideos.csv', engine='python')
us = pd.read_csv('USvideos.csv')

# %%
#Function that reads json file and returns dictionary with category id as key and category title as value
def read_json_files(filename):
    json = pd.read_json(filename)
    Dict = {}
    for item in json['items']: 

        category_id = item['id']
        category = item['snippet']['title']
        Dict[category_id] = category
        
    #check if category id 29 exists in dict - for some regions this id is missing in the json file for some reason
    if not('29' in Dict):
        Dict['29'] = 'Nonprofits & Activism'
        
    return Dict

# %%
def clean_data(df, json_file):

    df_clean = df.copy()
    df_clean = df_clean.drop(['thumbnail_link'], axis=1)

    #change the type of date columns from object to datetime64[ns] to be able to change the formatting
    #publish time - timezone is UTC - coordinated universal time
    df_clean['trending_date'] = pd.to_datetime(df_clean['trending_date'], format = '%y.%d.%m')
    df_clean['publish_time'] = pd.to_datetime(df_clean['publish_time'], format = '%Y-%m-%dT%H:%M:%S.%f%z')

    #change the formatting of date columns
    df_clean['trending_date'] = df_clean['trending_date'].dt.strftime('%Y-%m-%d').astype('datetime64[ns]')
    df_clean['publish_time'] = df_clean['publish_time'].dt.strftime('%Y-%m-%d %H:%M:%S').astype('datetime64[ns]')

    #cleaning up tags column
    #replaces |" (first tag is not enclosed with "") and "|" with ',' and removes last trailing character "
    df_clean['tags'] = df_clean['tags'].replace(to_replace='"\|"|\|"',value=',', regex=True).str.rstrip('"')
    
    #replace the value [none] in tags column with NaN
    df_clean['tags'].replace('[none]', np.nan, inplace=True)
    
    #replace value 'Deleted video' in title column with NaN
    df_clean['title'].replace('Deleted video', np.nan, inplace=True)
    
    #create dictionary of category id's and values
    category_dict = read_json_files(json_file)

    #change category_id type to string and rename column
    df_clean['category_id'] = df_clean['category_id'].astype(str)
    df_clean = df_clean.rename(columns={'category_id':'category'})

    #replace id's with category name
    df_clean['category'] = df_clean['category'].apply(category_dict.get)
    
    return df_clean

# %%
canada_clean = clean_data(canada, 'CA_category_id.json')
germany_clean = clean_data(germany, 'DE_category_id.json')
france_clean = clean_data(france, 'FR_category_id.json')
uk_clean = clean_data(uk, 'GB_category_id.json')
india_clean = clean_data(india, 'IN_category_id.json')
japan_clean = clean_data(japan, 'JP_category_id.json')
korea_clean = clean_data(korea, 'KR_category_id.json')
mexico_clean = clean_data(mexico, 'MX_category_id.json')
russia_clean = clean_data(russia, 'RU_category_id.json')
us_clean = clean_data(us, 'US_category_id.json')

# %%
canada_clean.head()
germany_clean.head()
france_clean.head()
uk_clean.head()
india_clean.head()
japan_clean.head()
korea_clean.head()
mexico_clean.head()
russia_clean.head()
us_clean.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc    2017-11-14
# 1  0dBIkQ4Mz1M    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  d380meD0W0M    2017-11-14
# 4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#         category        publish_time  \
# 0          Music 2017-11-10 17:00:03
# 1         Comedy 2017-11-13 17:00:00
# 2         Comedy 2017-11-12 19:05:24
# 3  Entertainment 2017-11-12 18:01:41
# 4          Music 2017-11-09 11:04:14
#
#                                                 tags     views    likes  \
# 0  Eminem,Walk,On,Water,Aftermath/Shady/Interscop...  17158579   787425
# 1  plush,bad unboxing,unboxing,fan mail,idubbbztv...   1014651   127794
# 2  racist superman,rudy,mancuso,king,bach,racist,...   3191434   146035
# 3  ryan,higa,higatv,nigahiga,i dare you,idy,rhpc,...   2095828   132239
# 4  edsheeran,ed sheeran,acoustic,live,cover,offic...  33523622  1634130
#
#    dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0     43420         125882              False             False
# 1      1688          13030              False             False
# 2      5339           8181              False             False
# 3      1989          17518              False             False
# 4     21082          85067              False             False
#
#    video_error_or_removed                                        description
# 0                   False  Eminem's new track Walk on Water ft. Beyoncé i...
# 1                   False  STill got a lot of packages. Probably will las...
# 2                   False  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3                   False  I know it's been a while since we did this sho...
# 4                   False  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...
#       video_id trending_date  \
# 0  LgVi6y5QIjM    2017-11-14
# 1  Bayt7uQith4    2017-11-14
# 2  1ZAPwfrtAFY    2017-11-14
# 3  AHtypnRk7JE    2017-11-14
# 4  ZJ9We4bjcg0    2017-11-14
#
#                                                title            channel_title  \
# 0  Sing zu Ende! | Gesangseinlagen vom Feinsten |...                inscope21
# 1  Kinder ferngesteuert im Kiosk! Erwachsene abzo...  LUKE! Die Woche und ich
# 2  The Trump Presidency: Last Week Tonight with J...          LastWeekTonight
# 3                                Das Fermi-Paradoxon        100SekundenPhysik
# 4           18 SONGS mit Kelly MissesVlog (Sing-off)                     rezo
#
#         category        publish_time  \
# 0  Entertainment 2017-11-13 17:08:49
# 1         Comedy 2017-11-12 22:30:01
# 2  Entertainment 2017-11-13 07:30:00
# 3      Education 2017-11-12 15:00:01
# 4  Entertainment 2017-11-12 13:10:36
#
#                                                 tags    views   likes  \
# 0  inscope21,sing zu ende,gesangseinlagen,gesang,...   252786   35885
# 1  Kinder,ferngesteuert,Kinder ferngesteuert,luke...   797196   53576
# 2  last week tonight trump presidency,last week t...  2418783   97190
# 3  Physik,Wissenschaft,Technik,Science-Fiction,Au...   380247   31821
# 4  kelly,missesvlog,kelly song,bausa,bausa was du...   822213  100684
#
#    dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0       230           1539              False             False
# 1       302           1278              False             False
# 2      6146          12703              False             False
# 3       458           1955              False             False
# 4      2467          10244              False             False
#
#    video_error_or_removed                                        description
# 0                   False  Heute gibt es mal wieder ein neues Format... w...
# 1                   False  Kinder ferngesteuert! Kinder lassen sich sooo ...
# 2                   False  One year after the presidential election, John...
# 3                   False  ►Alle Videos: http://bit.ly/1fa7Tw3\n\n\n✚Snap...
# 4                   False  18 Song Mashup über den (veränderten) Beat von...
#       video_id trending_date  \
# 0  Ro6eob0LrCY    2017-11-14
# 1  Yo84eqYwP98    2017-11-14
# 2  ceqntSXE-10    2017-11-14
# 3  WuTFI5qftCE    2017-11-14
# 4  ee6OFs8TdEg    2017-11-14
#
#                                                title        channel_title  \
# 0           Malika LePen : Femme de Gauche - Trailer  Le Raptor Dissident
# 1  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...              Le Labo
# 2  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...      Daniil le Russe
# 3                    PAPY GRENIER - METAL GEAR SOLID    Joueur Du Grenier
# 4  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...    Aurelien Fontenoy
#
#         category        publish_time  \
# 0  Entertainment 2017-11-13 17:32:55
# 1  Entertainment 2017-11-12 15:00:02
# 2         Comedy 2017-11-13 17:00:38
# 3         Gaming 2017-11-12 17:00:02
# 4         Sports 2017-11-13 16:30:03
#
#                                                 tags   views  likes  dislikes  \
# 0         Raptor,Dissident,Expliquez,moi,cette,merde  212702  29282      1108
# 1                                                NaN  432721  14053       576
# 2              cartoon,pokémon,école,ours,мультфильм  482153  76203       477
# 3  Papy grenier,Metal Gear Solid,PS1,Tirage d'ore...  925222  85016       550
# 4  vélo,vtt,bmx,freestyle,bike,mtb,dirt,trottinet...  141695   8091        72
#
#    comment_count  comments_disabled  ratings_disabled  video_error_or_removed  \
# 0           3817              False             False                   False
# 1           1161              False             False                   False
# 2           9580              False             False                   False
# 3           4303              False             False                   False
# 4            481              False             False                   False
#
#                                          description
# 0  Dimanche.\n18h30.\nSoyez présents pour la vidé...
# 1  Le jeu de société: https://goo.gl/hhG1Ta\n\nGa...
# 2  Une nouvelle dose de dessins animés français e...
# 3  Nouvel ,épisode de Papy Grenier ! Ce mois-ci o...
# 4  Sauts à plus de 4 mètres de haut dans un tramp...
#       video_id trending_date  \
# 0  Jw1Y-zhQURU    2017-11-14
# 1  3s1rvMFUweQ    2017-11-14
# 2  n1WpP7iowLc    2017-11-14
# 3  PUTEiSjKwJU    2017-11-14
# 4  rHwDegptbI4    2017-11-14
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title         category        publish_time  \
# 0                  John Lewis    Howto & Style 2017-11-10 07:38:29
# 1         Saturday Night Live    Entertainment 2017-11-12 06:24:44
# 2                  EminemVEVO            Music 2017-11-10 17:00:03
# 3  Salford City Football Club           Sports 2017-11-13 02:30:38
# 4            Cute Girl Videos  News & Politics 2017-11-13 01:45:13
#
#                                                 tags     views   likes  \
# 0  christmas,john lewis christmas,john lewis,chri...   7224515   55681
# 1  SNL,Saturday Night Live,SNL Season 43,Episode ...   1053632   25561
# 2  Eminem,Walk,On,Water,Aftermath/Shady/Interscop...  17158579  787420
# 3  Salford City FC,Salford City,Salford,Class of ...     27833     193
# 4                                                NaN      9815      30
#
#    dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0     10247           9479              False             False
# 1      2294           2757              False             False
# 2     43420         125882              False             False
# 3        12             37              False             False
# 4         2             30              False             False
#
#    video_error_or_removed                                        description
# 0                   False  Click here to continue the story and make your...
# 1                   False  Musical guest Taylor Swift performs …Ready for...
# 2                   False  Eminem's new track Walk on Water ft. Beyoncé i...
# 3                   False  Salford drew 4-4 against the Class of 92 and F...
# 4                   False  Dashcam captures truck's near miss with child ...
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  zUZ1z7FwLc8    2017-11-14
# 2  10L1hZ9qa58    2017-11-14
# 3  N1vE8iiEg64    2017-11-14
# 4  kJzGH0PVQHQ    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#            category        publish_time  \
# 0  Film & Animation 2017-11-12 12:20:39
# 1   News & Politics 2017-11-13 05:43:56
# 2     Entertainment 2017-11-12 15:48:08
# 3            Comedy 2017-11-12 07:08:48
# 4     Entertainment 2017-11-13 01:14:16
#
#                                                 tags    views  likes  \
# 0  sharry mann,sharry mann new song,sharry mann c...  1096327  33966
# 1  पीरियड्स के समय,पेट पर पति करता ऐसा,देखकर दंग ...   590101    735
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...   473988   2011
# 3  Eruma Saani,Tamil Comedy Videos,Films,Movies,H...  1242680  70353
# 4  Filmylooks,latest news,telugu movies,telugu ne...   464015    492
#
#    dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0       798            882              False             False
# 1       904              0               True             False
# 2       243            149              False             False
# 3      1624           2684              False             False
# 4       293             66              False             False
#
#    video_error_or_removed                                        description
# 0                   False  Presenting Sharry Mann latest Punjabi Song  Cu...
# 1                   False  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...
# 2                   False  Watch Stylish Star Allu Arjun @ ChaySam Weddin...
# 3                   False  This video showcases the difference between pe...
# 4                   False  why Samantha became EMOTIONAL @ Samantha naga ...
#       video_id trending_date  \
# 0  5ugKfHgsmYw    2018-02-07
# 1  ohObafdd34Y    2018-02-07
# 2  aBr2kKAHN6M    2018-02-07
# 3  5wNnwChvmsQ    2018-02-07
# 4  B7J47qFvdsk    2018-02-07
#
#                                                title  \
# 0  é™¸è‡ªãƒ˜ãƒªã€�åž‚ç›´ã�«è�½ä¸‹ï¼�è·¯ä¸Šã�®è»Šã...
# 1  ã‚¤ãƒƒãƒ†Q ã�Šç¥­ã‚Šç”·å®®å·�Ã—æ‰‹è¶Š å·¨å¤§ãƒ...
# 2                              Live Views of Starman
# 3  æ�±äº¬ãƒ‡ã‚£ã‚ºãƒ‹ãƒ¼ãƒªã‚¾ãƒ¼ãƒˆã�®å…ƒã‚­ãƒ£ã...
# 4  æ¦®å€‰å¥ˆã€…ã€�è¡�æ’ƒã�®æ­»ã‚“ã� ã�µã‚Šï¼�æ˜ ç...
#
#                     channel_title              category        publish_time  \
# 0  æ™‚äº‹é€šä¿¡æ˜ åƒ�ã‚»ãƒ³ã‚¿ãƒ¼       News & Politics 2018-02-06 03:04:37
# 1  ç¥žè°·ã�ˆã‚Šã�ª Kamiya Erina 2      Film & Animation 2018-02-06 04:01:56
# 2                          SpaceX  Science & Technology 2018-02-06 21:38:22
# 3           ã‚¢ã‚·ã‚¿ãƒŽãƒ¯ãƒ€ã‚¤       News & Politics 2018-02-06 06:08:49
# 4           ã‚·ãƒ�ãƒžãƒˆã‚¥ãƒ‡ã‚¤      Film & Animation 2018-02-06 02:30:00
#
#                                                 tags    views   likes  \
# 0  äº‹æ•…,ä½�è³€,ä½�è³€çœŒ,ãƒ˜ãƒªã‚³ãƒ—ã‚¿ãƒ¼,ãƒ˜...   188085     591
# 1                                                NaN    90929     442
# 2                                                NaN  6408303  165892
# 3                              ã‚¢ã‚·ã‚¿ãƒŽãƒ¯ãƒ€ã‚¤    96255    1165
# 4                                                NaN   108408    1336
#
#    dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0       189              0               True             False
# 1        88            174              False             False
# 2      2331           3006              False             False
# 3       277            545              False             False
# 4        74            201              False             False
#
#    video_error_or_removed                                        description
# 0                   False  ä½�è³€çœŒç¥žåŸ¼å¸‚ã�®æ°‘å®¶ã�«å¢œè�½ã�—ã�Ÿé™¸ä...
# 1                   False                                                NaN
# 2                   False                                                NaN
# 3                   False  æ�±äº¬ãƒ‡ã‚£ã‚ºãƒ‹ãƒ¼ãƒªã‚¾ãƒ¼ãƒˆã�®å…ƒã‚­ãƒ£ã...
# 4                   False  å®¶ã�«å¸°ã�£ã�¦ã��ã�Ÿã‚µãƒ©ãƒªãƒ¼ãƒžãƒ³ã�®ã�˜ã...
#       video_id trending_date  \
# 0  RxGQe4EeEpA    2017-11-14
# 1  hH7wVE8OlQ0    2017-11-14
# 2  9V8bnWUmE9U    2017-11-14
# 3  0_8py-t5R80    2017-11-14
# 4  bk55RbxiQdI    2017-11-14
#
#                                                title  \
# 0           ì¢‹ì•„ by ë¯¼ì„œ_ìœ¤ì¢…ì‹ _ì¢‹ë‹ˆ ë‹µê°€
# 1                 JSA ê·€ìˆœ ë¶�í•œêµ° ì´�ê²© ë¶€ìƒ�
# 2  ë‚˜ëª°ë�¼íŒ¨ë°€ë¦¬ ìš´ë�™í™” ì˜�ìƒ� 2íƒ„ (ë¹¼ë...
# 3  á„‹á…µá„†á…§á†¼á„‡á…¡á†¨ ì¶œêµ­ í˜„ìž¥, ë†“ì¹˜...
# 4  ê¹€ìž¥ê²¸ì�€ ë¬¼ëŸ¬ê°”ë‹¤ MBC ë…¸ì¡° í™˜í˜¸ì™€...
#
#                channel_title         category        publish_time  \
# 0         ë�¼í‘¸ë§ˆì½”ë¦¬ì•„   People & Blogs 2017-11-13 07:07:36
# 1                     Edward  News & Politics 2017-11-13 10:59:16
# 2  ë‚˜ëª°ë�¼íŒ¨ë°€ë¦¬ í•«ì‡¼   People & Blogs 2017-11-11 07:16:08
# 3            ë¯¸ë””ì–´ëª½êµ¬  News & Politics 2017-11-12 11:19:52
# 4                     NocutV  News & Politics 2017-11-13 11:08:59
#
#                                                 tags   views  likes  dislikes  \
# 0    ë�¼í‘¸ë§ˆ,ìœ¤ì¢…ì‹ ,ì¢‹ë‹ˆ,ì¢‹ì•„,ìƒ¬ë ˆ,ë¯¼ì„œ  156130   1422        40
# 1  JSA,ê·€ìˆœ,ë¶�í•œêµ°,ì´�ê²©,ë¶€ìƒ�,JSA ê·€ìˆœ ...   76533    211        28
# 2  ì•„ë””ë‹¤ìŠ¤,ë¹¼ë¹¼ë¡œ,í•«ì‡¼,ë‚˜ëª°ë�¼íŒ¨ë°€ë...  421409   5112       166
# 3  ì�´ëª…ë°•,ì�´ëª…ë°• ì¶œêµ­ê¸ˆì§€,ì�´ëª…ë°• ì¶œ...  222850   2093       173
# 4  nocutV,ë…¸ì»·V,CBS,mbc,ê¹€ìž¥ê²¸,í•´ìž„,í—ˆì�¼í›„   84466   1094       109
#
#    comment_count  comments_disabled  ratings_disabled  video_error_or_removed  \
# 0            272              False             False                   False
# 1            113              False             False                   False
# 2            459              False             False                   False
# 3           1219              False             False                   False
# 4            450              False             False                   False
#
#                                          description
# 0  ìœ¤ì¢…ì‹  'ì¢‹ë‹ˆ'ì�˜ ë‹µê°€ 'ì¢‹ì•„' ìµœì´ˆ ê...
# 1  [ì±„ë„�Aë‹¨ë�…]åŒ— ë³‘ì‚¬ í˜„ìž¬ 'ì�˜ì‹�ë¶ˆëª…...
# 2            í�¼ê°€ì‹¤ë•Œ ê¼­ ì¶œì²˜ ë¶€íƒ�ë“œë ¤ìš”
# 3    ë‹¤ìŠ¤ëŠ” ëˆ„êµ¬ê²�ë‹ˆê¹Œ ë“£ê³  ë‚œ í›„ í‘œì •
# 4  ê¹€ìž¥ê²¸ MBC ì‚¬ìž¥ì�´ ê²°êµ­ í•´ìž„ë��ë‹¤.\n...
#       video_id trending_date  \
# 0  SbOwzAl9ZfQ    2017-11-14
# 1  klOV6Xh-DnI    2017-11-14
# 2  6L2ZF7Qzsbk    2017-11-14
# 3  hcY52MFWMDM    2017-11-14
# 4  _OXDcGPVAa4    2017-11-14
#
#                                                title  \
# 0                     CapÃ­tulo 12 | MasterChef 2017
# 1  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2           LOUIS CKAGÃ“ - EL PULSO DE LA REPÃšBLICA
# 3   Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4           DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
#
#                channel_title         category        publish_time  \
# 0            MasterChef 2017    Entertainment 2017-11-13 06:06:22
# 1   Micky Contreras Martinez   People & Blogs 2017-11-13 05:11:58
# 2  El Pulso De La RepÃºblica  News & Politics 2017-11-13 17:00:02
# 3                   Casanare  News & Politics 2017-11-13 03:47:10
# 4                      Musas    Howto & Style 2017-11-13 19:17:48
#
#                                                 tags   views  likes  dislikes  \
# 0  MasterChef Junior 2017,TV Azteca,recetas,cocin...  310130   4182       361
# 1                                    La Voz Mexico 7  104972    271       174
# 2  Chumel Torres,El Pulso de la Republica,noticia...  136064  10105       266
# 3             temblor,costa rica,sismo en costa rica   96153    378       171
# 4  MUSAS,lesslie,karen,hacks,perros,dogs,trucos,l...  499965  57781       681
#
#    comment_count  comments_disabled  ratings_disabled  video_error_or_removed  \
# 0           1836              False             False                   False
# 1            369              False             False                   False
# 2            607              False             False                   False
# 3            208              False             False                   False
# 4           7428              False             False                   False
#
#                                          description
# 0  Disfruta la presencia del Chef Torreblanca en ...
# 1  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2  La canciÃ³n del principio se llama â€œEste esp...
# 3  El video es de un Walmart en el pais centroame...
# 4  MI HERMANO NARRA MI RUTINA DE MAQUILLAJE\nhttp...
#       video_id trending_date  \
# 0  gDuslQ9avLc    2017-11-14
# 1  AOCJIFEA_jE    2017-11-14
# 2  VAWNQDgwwOM    2017-11-14
# 3  gknkFwKQfHg    2017-11-14
# 4  3sYvZcwzZr8    2017-11-14
#
#                                                title       channel_title  \
# 0  Ð—Ð°Ñ…Ð°Ñ€ Ð¸ ÐŸÐ¾Ð»Ð¸Ð½Ð° ÑƒÑ‡Ð°Ñ‚Ñ�Ñ� Ñ�ÐºÐ¾...  Ð¢â€”Ð– Ð‘ÐžÐ“Ð�Ð§
# 1  Ð‘Ð¸Ñ€Ð¶Ð° ÐœÐµÐ¼Ð¾Ð² #29. Ð‘Ð¾Ð»ÑŒÑˆÐ¾Ð¸Ì† Ð²...        Druzhko Show
# 2  Ð¥Ð�Ð™ÐŸ ÐšÐ­ÐœÐŸ - Ð¡Ð’ÐžÐ™ Ð¡Ð Ð•Ð”Ð˜ Ð§Ð£Ð–...            Ð®Ð»Ð¸Ðº
# 3  Ð¡Ð¾Ñ‡Ð½Ð°Ñ� ÐºÐµÑ�Ð°Ð´Ð¸Ð»ÑŒÑ� Ñ� ÐºÑƒÑ€Ð¸Ñ†ÐµÐ¹            Hochland
# 4  ÐšÐ›Ð˜ÐŸÐ« Ð ÐžÐ”Ð˜Ð¢Ð•Ð›Ð•Ð™ Ð�Ð� Ð¨ÐšÐžÐ›Ð¬Ð...    Ð¡Ð¾Ð²ÐµÑ€Ð³Ð¾Ð½
#
#          category        publish_time  \
# 0  People & Blogs 2017-11-13 09:09:31
# 1  People & Blogs 2017-11-13 17:32:11
# 2   Entertainment 2017-11-13 16:11:31
# 3  People & Blogs 2017-11-13 06:51:10
# 4   Entertainment 2017-11-13 16:52:36
#
#                                                 tags   views  likes  dislikes  \
# 0  Ð·Ð°Ñ…Ð°Ñ€ Ð¸ Ð¿Ð¾Ð»Ð¸Ð½Ð°,ÑƒÑ‡Ð¸Ð¼Ñ�Ñ� Ñ�ÐºÐ¾...   62408    334       190
# 1  Ð±Ð¸Ñ€Ð¶Ð° Ð¼ÐµÐ¼Ð¾Ð²,Ð»ÐµÐ² ÑˆÐ°Ð³Ð¸Ð½Ñ�Ð½,Ð¼...  330043  43841      2244
# 2  ÑŽÐ¼Ð¾Ñ€,ÐºÐ¾Ð¼ÐµÐ´Ð¸Ñ�,Ð²Ð»Ð¾Ð³,Ð±Ð»Ð¾Ð³,Ñ�Ð¼...  424596  49854       714
# 3  Ñ…Ð¾Ñ…Ð»Ð°Ð½Ð´,Ñ�Ñ‹Ñ€,Ñ€ÐµÑ†ÐµÐ¿Ñ‚Ñ‹,ÐºÐ°Ðº Ð¿...  112851   3566       122
# 4  Ð¡Ð¾Ð²ÐµÑ€Ð³Ð¾Ð½,Sovergon,ÐºÐ»Ð¸Ð¿Ñ‹,Ñ€Ð¾Ð´Ð¸Ñ...  243469  36216       631
#
#    comment_count  comments_disabled  ratings_disabled  video_error_or_removed  \
# 0             50              False             False                   False
# 1           2977              False             False                   False
# 2           2944              False             False                   False
# 3             80              False             False                   False
# 4           1692              False             False                   False
#
#                                          description
# 0  Ð—Ð½Ð°ÐºÐ¾Ð¼ÑŒÑ‚ÐµÑ�ÑŒ, Ñ�Ñ‚Ð¾ Ð—Ð°Ñ…Ð°Ñ€ Ð¸ Ð...
# 1  Ð’ 29 Ð²Ñ‹Ð¿ÑƒÑ�ÐºÐµ Ð”Ñ€ÑƒÐ¶ÐºÐ¾ Ð¨Ð¾Ñƒ Ð¡ÐµÑ...
# 2  http://kapitany.ru/!Yulik.cap - Ð¤Ð°ÐºÑƒÐ»ÑŒÑ‚...
# 3  *** ÐºÐ°Ðº Ð³Ð¾Ñ‚Ð¾Ð²Ð¸Ñ‚ÑŒ Ñ€ÐµÑ�Ñ‚Ð¾Ñ€Ð°Ð½Ð½...
# 4  â�� ÐšÐžÐ�ÐšÐ£Ð Ð¡ ÐšÐ�ÐŸÐ˜Ð¢Ð�Ð�Ð«: http://ka...
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#          category        publish_time  \
# 0  People & Blogs 2017-11-13 17:13:01
# 1   Entertainment 2017-11-13 07:30:00
# 2          Comedy 2017-11-12 19:05:24
# 3   Entertainment 2017-11-13 11:00:04
# 4   Entertainment 2017-11-12 18:01:41
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency,last week t...  2418783   97185
# 2  racist superman,rudy,mancuso,king,bach,racist,...  3191434  146033
# 3  rhett and link,gmm,good mythical morning,rhett...   343168   10172
# 4  ryan,higa,higatv,nigahiga,i dare you,idy,rhpc,...  2095731  132235
#
#    dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0      2966          15954              False             False
# 1      6146          12703              False             False
# 2      5339           8181              False             False
# 3       666           2146              False             False
# 4      1989          17518              False             False
#
#    video_error_or_removed                                        description
# 0                   False  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1                   False  One year after the presidential election, John...
# 2                   False  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3                   False  Today we find out if Link is a Nickelback amat...
# 4                   False  I know it's been a while since we did this sho...

# %%
ca = canada_clean.copy()
ca['country'] = 'Canada'

de = germany_clean.copy()
de['country'] = 'Germany'

fr = france_clean.copy()
fr['country'] = 'France'

gb = uk_clean.copy()
gb['country'] = 'Great Britain'

ind = india_clean.copy()
ind['country'] = 'India'

jp = japan_clean.copy()
jp['country'] = 'Japan'

kr = korea_clean.copy()
kr['country'] = 'Korea'

mx = mexico_clean.copy()
mx['country'] = 'Mexico'

ru = russia_clean.copy()
ru['country'] = 'Russia'

usa = us_clean.copy()
usa['country'] = 'USA'

all_data = pd.concat([ca, de, fr, gb, ind, jp, kr, mx, ru, usa])

# %%
all_data.shape
all_data.video_id.value_count
# Out:
# (375942, 16)

# %%
import matplotlib.pyplot as plt

# allows to output plots in the notebook
# %matplotlib inline 

# Set the default style
plt.style.use("ggplot")

# %%
sorted_data = all_data.sort_values(by=["title", "trending_date"])
sorted_data["time_to_trending"] = sorted_data.trending_date.dt.date - sorted_data.publish_time.dt.date
# This is a bit of a hack so that we could find the maximum and minimum time between trending_date and publish time in the next step
sorted_data["trending_time"] = sorted_data.trending_date.dt.date - sorted_data.publish_time.dt.date

# %%
# Group videos by titles (find unique videos) and create a dataframe of results
# There are two trending times: max and min difference between trending_date and publish_time
unique_videos = sorted_data.groupby(["video_id", "title", "channel_title", "category", "publish_time", "country"], as_index=False).agg({"trending_date": min, "time_to_trending": min, "trending_time": max})

# Difference between max and min trending time is how long the video was in the trending page
# Add 1 day to all trending durations (if the video was trending on 2 days, then trending time will be 2 instead of 1)
unique_videos["trending_time"] = unique_videos["trending_time"] - unique_videos["time_to_trending"] + pd.Timedelta("1 day")

# %%
# Since this gives more than 10 (nr of countries) rows for some video ids, then some additional grouping must be done.
# See videos with video ids below for more info
unique_videos.video_id.value_counts()
# Out:
# #NAME?         1544
# FeRi86DcfyA      16
# qUmfriZoMw0      13
# tjA7nAHOAww      12
# Jz50eTT6y8g      11
# 4xTpw-05J0k      11
# iWZmdoY1aTE      10
# g4Hbz2jLxvQ      10
# 9_LIP7qguYw      10
# elwTgpHlty0      10
# _y2-Aj53sxw      10
# u9Mv98Gr5pY      10
# _I_D_8Z4sJE      10
# ogfYd705cRs      10
# tCXGJQYZ9JA      10
# OrnpSe4OChM      10
# XiHiW4N7-bo      10
# DkeiKbqa02g      10
# pVxOVlm_lE8      10
# NEoVjmfYlJ8       9
# 9v_rtaye2yY       9
# 2tDKp41nrw8       9
# 4uTNVumfm84       9
# ffxKSjUwKdU       9
# WS7f5xpGYn8       9
# NooW_RbfdWI       9
# aj8mN_7Apcw       9
# qZHycHI3F1Q       9
# oSEeK9yDNQI       9
# iN8zmmCRqUA       9
#                ...
# Ep1F_xyzooc       1
# vunb6bPnjtY       1
# Cyf1eXYE9Bw       1
# Gv80WTp2tfU       1
# Y1yfEJB6S1k       1
# iiKRkchB29E       1
# UvjdPQs2kwU       1
# z7lDRmd-dCs       1
# d3G6WDI_i9s       1
# G5E2yL_aKCQ       1
# hxwaDIKpM0o       1
# F-gPzbuYCOI       1
# x5uEgKRp_Ug       1
# 6ujqyGGTV7g       1
# FN-FW_yk5ko       1
# nUCzMtiAieg       1
# zmXzqT2RTxg       1
# 9ceUa5HRvag       1
# 6ajCr0Lih4I       1
# cOxjB2zLBVQ       1
# C-_vayF1K40       1
# AjMBDpRXsYA       1
# 2xd9v86rf8k       1
# rtgpIcwVYnI       1
# vBsb1FN6YD4       1
# MbR2qevSXjQ       1
# UOmolLOQ7Rs       1
# H_kZsbyHwnc       1
# bp5U_bjcCT8       1
# zQYarS9LYgk       1
# Name: video_id, Length: 184250, dtype: int64

# %%
# Do some additional grouping to account for the fact that some videos had changed titles/categories or had been published multiple times
unique_videos = unique_videos.groupby(["video_id", "channel_title", "country"], as_index=False).agg({"title": "first", "publish_time": "first", "category": "last", "trending_date": min, "time_to_trending": min, "trending_time": max})
unique_videos.video_id.value_counts()
# Out:
# #NAME?         1278
# pVxOVlm_lE8      10
# iWZmdoY1aTE      10
# DkeiKbqa02g      10
# XiHiW4N7-bo      10
# tCXGJQYZ9JA      10
# u9Mv98Gr5pY      10
# g4Hbz2jLxvQ      10
# OrnpSe4OChM      10
# tjA7nAHOAww      10
# CX11yw6YL1w       9
# FlsCjmMhFmw       9
# ffxKSjUwKdU       9
# 1FJD7jZqZEk       9
# q8v9MvManKE       9
# VYOjWnS4cMY       9
# elwTgpHlty0       9
# WS7f5xpGYn8       9
# kX0vO4vlJuU       9
# D_6QmL6rExk       9
# iN8zmmCRqUA       9
# dzxFdtWmjto       9
# 7C2z4GqqS5E       9
# p8npDG2ulKQ       9
# UUkn-enk2RU       9
# YBpdL9hSac4       9
# tlILlcCE8Sc       9
# NooW_RbfdWI       9
# VY1eFxgRR-k       9
# r-3iathMo7o       9
#                ...
# gWMDP8OAs8U       1
# 7NkjDy3GLE8       1
# G6-Ey3oNaPI       1
# cLbEIK_GhjU       1
# 0B-isEukfyY       1
# xqAkjHmks-c       1
# paYuDj6iucU       1
# BADL1MZCQFE       1
# Mil21SayIbg       1
# LwU1E0fSiCI       1
# uD8f0QHfomM       1
# G8ewEQqQNsk       1
# CNep3y4jKnI       1
# YAlhV9g2J0Q       1
# HJplkRa1H5s       1
# JUR5OtLNcVI       1
# 5_g3e6BGx0E       1
# ptJq7Vaf2PA       1
# F5PuQ9uogOg       1
# 53WWI-b3ek8       1
# 4oG2EGk797A       1
# 2YZMuUc1NdA       1
# M26uJlp9ASI       1
# FciPpWOp2iw       1
# 8zBDQ3tjbWE       1
# jb60YbZqyv4       1
# oJ8Cf0vWmxE       1
# j-vP27uNpU8       1
# isI6DqxAr7s       1
# zQYarS9LYgk       1
# Name: video_id, Length: 184250, dtype: int64

# %%
unique_videos.trending_time.value_counts()
# Out:
# 1 days     144298
# 2 days      37978
# 3 days      12673
# 4 days       4911
# 5 days       2418
# 6 days       1264
# 7 days        959
# 8 days        533
# 9 days        420
# 11 days       367
# 12 days       341
# 13 days       334
# 10 days       330
# 14 days       280
# 15 days       175
# 16 days       128
# 17 days       120
# 18 days        99
# 20 days        95
# 19 days        83
# 21 days        74
# 36 days        73
# 22 days        62
# 23 days        54
# 28 days        49
# 24 days        48
# 25 days        45
# 37 days        44
# 27 days        42
# 35 days        41
# 26 days        40
# 29 days        39
# 30 days        30
# 34 days        27
# 31 days        27
# 32 days        25
# 33 days        25
# 38 days         3
# Name: trending_time, dtype: int64

# %%
print("Average time until a video trends is:", unique_videos.time_to_trending.mean())
print("Median time until a video trends is:", unique_videos.time_to_trending.median())
print("Average time a video stays in trending is:", unique_videos.trending_time.mean())
print("Median time a video stays in trending is:", unique_videos.trending_time.median())
# Out:
# Average time until a video trends is: 3 days 05:53:16.697258
# Median time until a video trends is: 1 days 00:00:00
# Average time a video stays in trending is: 1 days 18:01:39.634627
# Median time a video stays in trending is: 1 days 00:00:00

# %%
countries = ["Canada", "Germany", "Great Britain", "France", "USA", "India", "Japan", "Korea", "Mexico", "Russia"]
country_stats = pd.DataFrame({"Country": countries})

# %%
avg_time_to_trending = []
median_time_to_trending = []
avg_time_in_trending = []
median_time_in_trending = []

# For each country in the list of countries (defined above)
for c in countries:
    # Add median time until video makes it to trending by country
    median_time_to_trending.append(unique_videos[unique_videos.country == c].time_to_trending.median())
    avg_time_to_trending.append(unique_videos[unique_videos.country == c].time_to_trending.mean())
    median_time_in_trending.append(unique_videos[unique_videos.country == c].trending_time.median())
    avg_time_in_trending.append(unique_videos[unique_videos.country == c].trending_time.mean())
    
country_stats["average_time_to_trending"] = avg_time_to_trending
country_stats["median_time_to_trending"] = median_time_to_trending
country_stats["average_time_in_trending"] = avg_time_in_trending
country_stats["median_time_in_trending"] = median_time_in_trending
country_stats

# Currently, something is fucked up with the plots, because y-axis values are wrong
country_stats.plot.bar(x="Country", y=["average_time_to_trending", "median_time_to_trending"])
country_stats.plot.bar(x="Country", y=["average_time_in_trending", "median_time_in_trending"])
# Out:
#          Country average_time_to_trending median_time_to_trending  \
# 0         Canada   2 days 21:00:15.028239                  1 days
# 1        Germany   1 days 13:39:54.816414                  1 days
# 2  Great Britain  37 days 01:12:35.420589                  2 days
# 3         France   2 days 19:25:50.524767                  1 days
# 4            USA  22 days 11:42:20.710468                  2 days
# 5          India   1 days 07:24:36.570180                  1 days
# 6          Japan   1 days 09:10:42.866967                  1 days
# 7          Korea   1 days 23:09:52.964824                  1 days
# 8         Mexico   1 days 18:56:46.903876                  1 days
# 9         Russia   2 days 05:21:29.163229                  1 days
#
#   average_time_in_trending median_time_in_trending
# 0   1 days 16:01:09.542440                  1 days
# 1   1 days 08:57:57.537796                  1 days
# 2  12 days 09:54:16.726389                 10 days
# 3   1 days 07:50:12.417851                  1 days
# 4   6 days 16:56:17.051241                  6 days
# 5   1 days 23:18:08.585472                  2 days
# 6   1 days 02:46:28.782761                  1 days
# 7   1 days 23:37:45.326633                  2 days
# 8   1 days 04:26:48.497079                  1 days
# 9   1 days 03:58:37.344024                  1 days
# /usr/local/lib/python3.5/dist-packages/pandas/plotting/_core.py:223: FutureWarning: Passing integers to fillna is deprecated, will raise a TypeError in a future version.  To retain the old behavior, pass pd.Timedelta(seconds=n) instead.
#   data = data.fillna(fillna)
